# %%
def fib(n): 
    assert n>=0 and int (n) == n,"Fibonacci is only for positive number"
    if n in [0,1]: 
        return n
    else: 
        return fib(n-1)+fib(n-2)

fib(5)
# Out:
# 5

# %%
fib(2)
# Out:
# 1
