# %%
def sumOfDigits(n):
    assert n>0 and int (n) == n, "Positive Integer"
    if n == 0: 
        return 0
    else:    
        return int(n%10) + sumOfDigits(n/10)

sumOfDigits(4)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 8
#       5     else:
#       6         return int(n%10) + sumOfDigits(n/10)
# ----> 8 sumOfDigits(4)
#
# Cell In[5], line 6, in sumOfDigits(n)
#       4     return 0
#       5 else:
# ----> 6     return int(n%10) + sumOfDigits(n/10)
#
# Cell In[5], line 2, in sumOfDigits(n)
#       1 def sumOfDigits(n):
# ----> 2     assert n>0 and int (n) == n, "Positive Integer"
#       3     if n == 0:
#       4         return 0
#
# AssertionError: Positive Integer

# %%
sumOfDigits(12)
# Out:
# 3

# %%
sumOfDigits(1114)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sumOfDigits(1114)
#
# NameError: name 'sumOfDigits' is not defined
